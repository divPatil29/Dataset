# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/Sentiment_Alan_Walkar.csv")

print(data.head(20))
print(data.info())
# Out:
#     id                      author  \
# 0    1  @Bestsongscollection-fj3op
# 1    2          @raquellinchen1106
# 2    3          @raquellinchen1106
# 3    4           @daisybanchro3611
# 4    5           @daisybanchro3611
# 5    6              @sugiyanto3861
# 6    7          @ChiAnhHuynh-pp8bh
# 7    8                @anithak2399
# 8    9   @andysmetrotrainvlogs8163
# 9   10   @andysmetrotrainvlogs8163
# 10  11                @Yuki-yuuji-
# 11  12            @IhirweHyacinthe
# 12  13   @andysmetrotrainvlogs8163
# 13  14          @AkshayKumar-vi9sx
# 14  15            @user-je1rc4gt3d
# 15  16            @user-qt8bm5pj9j
# 16  17               @cristine2864
# 17  18    @FreimariHernandez-il8gu
# 18  19       @EdwardLeonardo-vm1my
# 19  20       @EdwardLeonardo-vm1my
#
#                                           description  \
# 0   Music 2023 New Songs - Top Best English Songs ...
# 1   ​@@linnlinn57340\'\'\'\'\'\'\'\'\'\'\'\'\'o\'\...
# 2                                   ​@@linnlinn5734\'
# 3                                                   1
# 4                                   ​@@linnlinn5734😊1
# 5                                      8:33 8:35 8:36
# 6                                     I ❤ alan walker
# 7                                       Amazing songs
# 8   I Like The Singer Alan Walker And he’s a Great...
# 9   About Alan Walker He’s Such An Excellent Music...
# 10                                 Legend never dies❤
# 11                                      Wonderful hit
# 12  I Do Love  Like Listening To Alan Walker’s Mus...
# 13                                              ❤❤❤❤❤
# 14                                          Very good
# 15                                     ❤🎉thanks for 🎉
# 16  Almost all of my favorite songs are made by Al...
# 17                                                  😢
# 18                                               ❤❤❤❤
# 19                                  The biss song ❤❤❤
#
#                                                  guid  \
# 0                          UgylxIqy90o0KgrPxMV4AaABAg
# 1   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tcc4N_ov6C
# 2   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tcc5EhrLAE
# 3   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9teyaaT1BTh
# 4   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9teyc7ElVch
# 5   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tpP7YFs0Yp
# 6                          Ugwx-iDXN4HhNRa9LwV4AaABAg
# 7                          UgwfToNWC9uBgX0Sjgx4AaABAg
# 8                          UgwQeqK1AebQ6IvhDwh4AaABAg
# 9                          UgxVd5u-DZ4HSpvAqVt4AaABAg
# 10                         Ugx2n4ojOeWRL5ydvzJ4AaABAg
# 11                         UgwRSXGLif35BCkXAOZ4AaABAg
# 12                         UgwTPcfDO6prWun1T0Z4AaABAg
# 13                         UgyDyvXdrG4Gef6bdz14AaABAg
# 14                         UgzbR3HcE-P0MsSi7eJ4AaABAg
# 15                         Ugz4xAT-htMwQp2cKzJ4AaABAg
# 16                         UgxJPFN3bK_MLzH3i414AaABAg
# 17                         UgzB622UdDDdeaY39k94AaABAg
# 18                         UgzB5pwEpyIOuZdUJ9V4AaABAg
# 19                         Ugxe09o3plMvq3jgWUt4AaABAg
#
#                             to  likecount  \
# 0                          NaN        771
# 1   @Bestsongscollection-fj3op          0
# 2   @Bestsongscollection-fj3op          1
# 3   @Bestsongscollection-fj3op         52
# 4   @Bestsongscollection-fj3op          0
# 5   @Bestsongscollection-fj3op         36
# 6                          NaN          0
# 7                          NaN          0
# 8                          NaN          0
# 9                          NaN          0
# 10                         NaN          0
# 11                         NaN          0
# 12                         NaN          0
# 13                         NaN          0
# 14                         NaN          0
# 15                         NaN          0
# 16                         NaN          0
# 17                         NaN          0
# 18                         NaN          0
# 19                         NaN          0
#
#                                                  link              pubdate  \
# 0   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-16 04:59:45
# 1   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-20 03:27:47
# 2   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-20 03:27:54
# 3   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-21 01:23:02
# 4   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-21 01:23:15
# 5   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-25 02:36:01
# 6   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-27 23:20:35
# 7   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-27 21:43:25
# 8   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-27 20:23:29
# 9   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-27 19:46:31
# 10  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-27 14:15:48
# 11  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-27 06:53:42
# 12  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-27 04:32:00
# 13  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-27 03:54:18
# 14  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-27 01:09:24
# 15  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-27 01:05:07
# 16  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-26 22:31:04
# 17  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-26 19:58:36
# 18  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-26 16:54:54
# 19  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-26 16:54:40
#
#     replycount                                              title  \
# 0          163  Music 2023 New Songs - Top Best English Songs ...
# 1            0  ​@@linnlinn57340\'\'\'\'\'\'\'\'\'\'\'\'\'o\'\...
# 2            0                                  ​@@linnlinn5734\'
# 3            0                                                  1
# 4            0                                  ​@@linnlinn5734😊1
# 5            0                                     8:33 8:35 8:36
# 6            0                                    I ❤ alan walker
# 7            0                                      Amazing songs
# 8            0  I Like The Singer Alan Walker And he’s a Great...
# 9            0  About Alan Walker He’s Such An Excellent Music...
# 10           0                                 Legend never dies❤
# 11           0                                      Wonderful hit
# 12           0  I Do Love  Like Listening To Alan Walker’s Mus...
# 13           0                                              ❤❤❤❤❤
# 14           0                                          Very good
# 15           0                                     ❤🎉thanks for 🎉
# 16           0  Almost all of my favorite songs are made by Al...
# 17           0                                                  😢
# 18           0                                               ❤❤❤❤
# 19           0                                  The biss song ❤❤❤
#
#                                      authorChannelUrl  Unnamed: 11
# 0   http://www.youtube.com/@Bestsongscollection-fj3op          NaN
# 1           http://www.youtube.com/@raquellinchen1106          NaN
# 2           http://www.youtube.com/@raquellinchen1106          NaN
# 3            http://www.youtube.com/@daisybanchro3611          NaN
# 4            http://www.youtube.com/@daisybanchro3611          NaN
# 5               http://www.youtube.com/@sugiyanto3861          NaN
# 6           http://www.youtube.com/@ChiAnhHuynh-pp8bh          NaN
# 7                 http://www.youtube.com/@anithak2399          NaN
# 8    http://www.youtube.com/@andysmetrotrainvlogs8163          NaN
# 9    http://www.youtube.com/@andysmetrotrainvlogs8163          NaN
# 10                http://www.youtube.com/@Yuki-yuuji-          NaN
# 11            http://www.youtube.com/@IhirweHyacinthe          NaN
# 12   http://www.youtube.com/@andysmetrotrainvlogs8163          NaN
# 13          http://www.youtube.com/@AkshayKumar-vi9sx          NaN
# 14            http://www.youtube.com/@user-je1rc4gt3d          NaN
# 15            http://www.youtube.com/@user-qt8bm5pj9j          NaN
# 16               http://www.youtube.com/@cristine2864          NaN
# 17    http://www.youtube.com/@FreimariHernandez-il8gu          NaN
# 18       http://www.youtube.com/@EdwardLeonardo-vm1my          NaN
# 19       http://www.youtube.com/@EdwardLeonardo-vm1my          NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2448 entries, 0 to 2447
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2448 non-null   int64
#  1   author            2448 non-null   object
#  2   description       2441 non-null   object
#  3   guid              2448 non-null   object
#  4   to                315 non-null    object
#  5   likecount         2448 non-null   int64
#  6   link              2448 non-null   object
#  7   pubdate           2448 non-null   object
#  8   replycount        2448 non-null   int64
#  9   title             2441 non-null   object
#  10  authorChannelUrl  2448 non-null   object
#  11  Unnamed: 11       0 non-null      float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 229.6+ KB
# None

# %%
data.drop_duplicates(inplace=True)

# %%
print(data.head(20))
print(data.info())
# Out:
#     id                      author  \
# 0    1  @Bestsongscollection-fj3op
# 1    2          @raquellinchen1106
# 2    3          @raquellinchen1106
# 3    4           @daisybanchro3611
# 4    5           @daisybanchro3611
# 5    6              @sugiyanto3861
# 6    7          @ChiAnhHuynh-pp8bh
# 7    8                @anithak2399
# 8    9   @andysmetrotrainvlogs8163
# 9   10   @andysmetrotrainvlogs8163
# 10  11                @Yuki-yuuji-
# 11  12            @IhirweHyacinthe
# 12  13   @andysmetrotrainvlogs8163
# 13  14          @AkshayKumar-vi9sx
# 14  15            @user-je1rc4gt3d
# 15  16            @user-qt8bm5pj9j
# 16  17               @cristine2864
# 17  18    @FreimariHernandez-il8gu
# 18  19       @EdwardLeonardo-vm1my
# 19  20       @EdwardLeonardo-vm1my
#
#                                           description  \
# 0   Music 2023 New Songs - Top Best English Songs ...
# 1   ​@@linnlinn57340\'\'\'\'\'\'\'\'\'\'\'\'\'o\'\...
# 2                                   ​@@linnlinn5734\'
# 3                                                   1
# 4                                   ​@@linnlinn5734😊1
# 5                                      8:33 8:35 8:36
# 6                                     I ❤ alan walker
# 7                                       Amazing songs
# 8   I Like The Singer Alan Walker And he’s a Great...
# 9   About Alan Walker He’s Such An Excellent Music...
# 10                                 Legend never dies❤
# 11                                      Wonderful hit
# 12  I Do Love  Like Listening To Alan Walker’s Mus...
# 13                                              ❤❤❤❤❤
# 14                                          Very good
# 15                                     ❤🎉thanks for 🎉
# 16  Almost all of my favorite songs are made by Al...
# 17                                                  😢
# 18                                               ❤❤❤❤
# 19                                  The biss song ❤❤❤
#
#                                                  guid  \
# 0                          UgylxIqy90o0KgrPxMV4AaABAg
# 1   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tcc4N_ov6C
# 2   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tcc5EhrLAE
# 3   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9teyaaT1BTh
# 4   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9teyc7ElVch
# 5   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tpP7YFs0Yp
# 6                          Ugwx-iDXN4HhNRa9LwV4AaABAg
# 7                          UgwfToNWC9uBgX0Sjgx4AaABAg
# 8                          UgwQeqK1AebQ6IvhDwh4AaABAg
# 9                          UgxVd5u-DZ4HSpvAqVt4AaABAg
# 10                         Ugx2n4ojOeWRL5ydvzJ4AaABAg
# 11                         UgwRSXGLif35BCkXAOZ4AaABAg
# 12                         UgwTPcfDO6prWun1T0Z4AaABAg
# 13                         UgyDyvXdrG4Gef6bdz14AaABAg
# 14                         UgzbR3HcE-P0MsSi7eJ4AaABAg
# 15                         Ugz4xAT-htMwQp2cKzJ4AaABAg
# 16                         UgxJPFN3bK_MLzH3i414AaABAg
# 17                         UgzB622UdDDdeaY39k94AaABAg
# 18                         UgzB5pwEpyIOuZdUJ9V4AaABAg
# 19                         Ugxe09o3plMvq3jgWUt4AaABAg
#
#                             to  likecount  \
# 0                          NaN        771
# 1   @Bestsongscollection-fj3op          0
# 2   @Bestsongscollection-fj3op          1
# 3   @Bestsongscollection-fj3op         52
# 4   @Bestsongscollection-fj3op          0
# 5   @Bestsongscollection-fj3op         36
# 6                          NaN          0
# 7                          NaN          0
# 8                          NaN          0
# 9                          NaN          0
# 10                         NaN          0
# 11                         NaN          0
# 12                         NaN          0
# 13                         NaN          0
# 14                         NaN          0
# 15                         NaN          0
# 16                         NaN          0
# 17                         NaN          0
# 18                         NaN          0
# 19                         NaN          0
#
#                                                  link              pubdate  \
# 0   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2448 non-null   int64
#  1   author            2448 non-null   object
#  2   description       2441 non-null   object
#  3   guid              2448 non-null   object
#  4   to                315 non-null    object
#  5   likecount         2448 non-null   int64
#  6   link              2448 non-null   object
#  7   pubdate           2448 non-null   object
#  8   replycount        2448 non-null   int64
#  9   title             2441 non-null   object
#  10  authorChannelUrl  2448 non-null   object
#  11  Unnamed: 11       0 non-null      float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 229.6+ KB
# None

# %%
import re

def clean_text(text):
    # Remove URLs
    text = re.sub(r'https://www.youtube.com/watch?v=', '..', text)
    text = re.sub(r'[https://www.youtube.com/watch?v=]', '', text)
    # Remove special characters and punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Convert to lowercase
    text = text.lower()
    return text

# %%
# data.drop('pubdate', inplace=True, axis=1)

data.drop('to', inplace=True, axis=1)

# %%
data['author'] = data['author'].apply(clean_text)

data['link'] = data['link'].apply(clean_text)

# %%
data['authorChannelUrl'] = data['authorChannelUrl'].apply(clean_text)

# %%
import re

def clean_text(text):
    # Check if the input is a string or NaN, and return an empty string if not
    if isinstance(text, str):
        # Remove URLs
        text = re.sub(r'http\S+', '', text)
        # Remove special characters and punctuation
        text = re.sub(r'[^\w\s]', '', text)
        # Remove numbers
        text = re.sub(r'\d+', '', text)
        # Convert to lowercase
        text = text.lower()
        return text
    else:
        return ""

# Apply the modified clean_text function to the 'description' column
data['description'] = data['description'].apply(clean_text)
data['title'] = data['title'].apply(clean_text)

# %%
print(data.head(20))
# Out:
#     id          author                                        description  \
# 0    1       bngllinfj  music  new songs  top best english songs   new...
# 1    2         rqllinn                                         linnlinnoo
# 2    3         rqllinn                                           linnlinn
# 3    4            dinr
# 4    5            dinr                                           linnlinn
# 5    6             gin
# 6    7          cianhn                                     i  alan walker
# 7    8             nik                                      amazing songs
# 8    9        ndrrinlg  i like the singer alan walker and hes a greate...
# 9   10        ndrrinlg  about alan walker hes such an excellent musici...
# 10  11           ykiji                                  legend never dies
# 11  12          iirhin                                      wonderful hit
# 12  13        ndrrinlg  i do love  like listening to alan walkers musi...
# 13  14          akkrix
# 14  15           rjrgd                                          very good
# 15  16            rqjj                                        thanks for
# 16  17            riin  almost all of my favorite songs are made by al...
# 17  18  fririhrnndzilg
# 18  19        edrdlnrd
# 19  20        edrdlnrd                                     the biss song
#
#                                                  guid  likecount  \
# 0                          UgylxIqy90o0KgrPxMV4AaABAg        771
# 1   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tcc4N_ov6C          0
# 2   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tcc5EhrLAE          1
# 3   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9teyaaT1BTh         52
# 4   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9teyc7ElVch          0
# 5   UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tpP7YFs0Yp         36
# 6                          Ugwx-iDXN4HhNRa9LwV4AaABAg          0
# 7                          UgwfToNWC9uBgX0Sjgx4AaABAg          0
# 8                          UgwQeqK1AebQ6IvhDwh4AaABAg          0
# 9                          UgxVd5u-DZ4HSpvAqVt4AaABAg          0
# 10                         Ugx2n4ojOeWRL5ydvzJ4AaABAg          0
# 11                         UgwRSXGLif35BCkXAOZ4AaABAg          0
# 12                         UgwTPcfDO6prWun1T0Z4AaABAg          0
# 13                         UgyDyvXdrG4Gef6bdz14AaABAg          0
