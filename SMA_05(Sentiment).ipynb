# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Alan_Walkar.csv")

# %%
df.head(5)
# Out:
#    id                      author  \
# 0   1  @Bestsongscollection-fj3op
# 1   2          @raquellinchen1106
# 2   3          @raquellinchen1106
# 3   4           @daisybanchro3611
# 4   5           @daisybanchro3611
#
#                                          description  \
# 0  Music 2023 New Songs - Top Best English Songs ...
# 1  ​@@linnlinn57340\'\'\'\'\'\'\'\'\'\'\'\'\'o\'\...
# 2                                  ​@@linnlinn5734\'
# 3                                                  1
# 4                                  ​@@linnlinn5734😊1
#
#                                                 guid  \
# 0                         UgylxIqy90o0KgrPxMV4AaABAg
# 1  UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tcc4N_ov6C
# 2  UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tcc5EhrLAE
# 3  UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9teyaaT1BTh
# 4  UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9teyc7ElVch
#
#                            to  likecount  \
# 0                         NaN        771
# 1  @Bestsongscollection-fj3op          0
# 2  @Bestsongscollection-fj3op          1
# 3  @Bestsongscollection-fj3op         52
# 4  @Bestsongscollection-fj3op          0
#
#                                                 link              pubdate  \
# 0  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-16 04:59:45
# 1  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-20 03:27:47
# 2  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-20 03:27:54
# 3  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-21 01:23:02
# 4  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-21 01:23:15
#
#    replycount                                              title  \
# 0         163  Music 2023 New Songs - Top Best English Songs ...
# 1           0  ​@@linnlinn57340\'\'\'\'\'\'\'\'\'\'\'\'\'o\'\...
# 2           0                                  ​@@linnlinn5734\'
# 3           0                                                  1
# 4           0                                  ​@@linnlinn5734😊1
#
#                                     authorChannelUrl  Unnamed: 11
# 0  http://www.youtube.com/@Bestsongscollection-fj3op          NaN
# 1          http://www.youtube.com/@raquellinchen1106          NaN
# 2          http://www.youtube.com/@raquellinchen1106          NaN
# 3           http://www.youtube.com/@daisybanchro3611          NaN
# 4           http://www.youtube.com/@daisybanchro3611          NaN

# %%
print(df.shape)
# Out:
# (2448, 12)

# %%
df.info()
df.pubdate.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2448 entries, 0 to 2447
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2448 non-null   int64
#  1   author            2448 non-null   object
#  2   description       2441 non-null   object
#  3   guid              2448 non-null   object
#  4   to                315 non-null    object
#  5   likecount         2448 non-null   int64
#  6   link              2448 non-null   object
#  7   pubdate           2448 non-null   object
#  8   replycount        2448 non-null   int64
#  9   title             2441 non-null   object
#  10  authorChannelUrl  2448 non-null   object
#  11  Unnamed: 11       0 non-null      float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 229.6+ KB
# pubdate
# 2023-09-18 22:43:17    3
# 2024-01-20 00:41:50    2
# 2023-08-18 20:45:23    2
# 2023-10-29 02:27:12    1
# 2023-10-29 02:27:39    1
#                       ..
# 2024-01-25 19:41:00    1
# 2024-01-25 14:54:33    1
# 2024-01-25 06:35:34    1
# 2024-01-25 04:13:01    1
# 2023-08-05 10:22:49    1
# Name: count, Length: 2444, dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Heat Map for missing values
plt.figure(figsize=(17, 5))
sns.heatmap(df.isnull(), cbar=True, yticklabels=False)
plt.xlabel("Column_Name", size=14, weight="bold")
plt.title("Places of missing values in column",fontweight="bold",size=17)
plt.show()

# %%
import plotly.graph_objects as go
Top_Title_Of_comments= df['title'].value_counts().head(10)

# %%
print (Top_Title_Of_comments)
# Out:
# title
# ❤                             33
# ❤❤❤                           12
# I just Loved this playlist    12
# nice                           9
# good                           8
# ❤❤❤❤❤                          8
# ❤❤                             7
# 👍                              7
# We live we love we lie         6
# Nice                           6
# Name: count, dtype: int64

# %%
import nltk

# %%
stop=nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# !pip install tweet-preprocessor
# Out:
# Collecting tweet-preprocessor
#   Downloading tweet_preprocessor-0.6.0-py3-none-any.whl (27 kB)
# Installing collected packages: tweet-preprocessor
# Successfully installed tweet-preprocessor-0.6.0

# %%
df=df.drop_duplicates('description')

# %%
df.head(5)
# Out:
#    id                      author  \
# 0   1  @Bestsongscollection-fj3op
# 1   2          @raquellinchen1106
# 2   3          @raquellinchen1106
# 3   4           @daisybanchro3611
# 4   5           @daisybanchro3611
#
#                                          description  \
# 0  Music 2023 New Songs - Top Best English Songs ...
# 1  ​@@linnlinn57340\'\'\'\'\'\'\'\'\'\'\'\'\'o\'\...
# 2                                  ​@@linnlinn5734\'
# 3                                                  1
# 4                                  ​@@linnlinn5734😊1
#
#                                                 guid  \
# 0                         UgylxIqy90o0KgrPxMV4AaABAg
# 1  UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tcc4N_ov6C
# 2  UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tcc5EhrLAE
# 3  UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9teyaaT1BTh
# 4  UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9teyc7ElVch
#
#                            to  likecount  \
# 0                         NaN        771
# 1  @Bestsongscollection-fj3op          0
# 2  @Bestsongscollection-fj3op          1
# 3  @Bestsongscollection-fj3op         52
# 4  @Bestsongscollection-fj3op          0
#
#                                                 link              pubdate  \
# 0  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-16 04:59:45
# 1  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-20 03:27:47
# 2  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-20 03:27:54
# 3  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-21 01:23:02
# 4  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-21 01:23:15
#
#    replycount                                              title  \
# 0         163  Music 2023 New Songs - Top Best English Songs ...
# 1           0  ​@@linnlinn57340\'\'\'\'\'\'\'\'\'\'\'\'\'o\'\...
# 2           0                                  ​@@linnlinn5734\'
# 3           0                                                  1
# 4           0                                  ​@@linnlinn5734😊1
#
#                                     authorChannelUrl  Unnamed: 11
# 0  http://www.youtube.com/@Bestsongscollection-fj3op          NaN
# 1          http://www.youtube.com/@raquellinchen1106          NaN
# 2          http://www.youtube.com/@raquellinchen1106          NaN
# 3           http://www.youtube.com/@daisybanchro3611          NaN
# 4           http://www.youtube.com/@daisybanchro3611          NaN

# %%
#Drop commentss which have empty text field
df['description'].replace(' ', np.nan, inplace=True)
df.dropna(subset=['description'], inplace=True)
len(df)
# Out:
# 2179

# %%
df = df.reset_index(drop=True)
df.sample(5)
# Out:
#         id                  author  \
# 321    350               @AT-se1hb
# 248    263     @karubangasimon1887
# 2022  2270      @ulugbekjumaev8345
# 200    211            @EdithNasser
# 1693  1891  @SuriyaGomesyourbestie
#
#                                             description  \
# 321                                        1:50 4:57:04
# 248                               This is so super Alan
# 2022                     Qòshiqlarga gap yòq supperr🎉🎉🎉
# 200                                       😊🎉🎉 love them
# 1693  ALAN WALKERS songs are so good my brain can’t ...
#
#                             guid   to  likecount  \
# 321   Ugy2r4Cn5guviEJCY9N4AaABAg  NaN          1
# 248   Ugynwqv6fwbJS-32UiF4AaABAg  NaN          6
# 2022  Ugwpz1VeMWdegPFGqL54AaABAg  NaN          1
# 200   Ugzse3f6eCiFtzDev-V4AaABAg  NaN          1
# 1693  Ugx3PVgycJdLbGqrAUp4AaABAg  NaN          1
#
#                                                    link              pubdate  \
# 321   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-03-21 22:51:27
# 248   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-03-29 15:06:07
# 2022  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-26 07:30:47
# 200   https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2024-04-05 08:31:35
# 1693  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-09-30 21:40:43
#
#       replycount                                              title  \
# 321            0                                       1:50 4:57:04
# 248            0                              This is so super Alan
# 2022           0                     Qòshiqlarga gap yòq supperr🎉🎉🎉
# 200            0                                      😊🎉🎉 love them
# 1693           1  ALAN WALKERS songs are so good my brain can’t ...
#
#                                    authorChannelUrl  Unnamed: 11
# 321                http://www.youtube.com/@AT-se1hb          NaN
# 248      http://www.youtube.com/@karubangasimon1887          NaN
# 2022      http://www.youtube.com/@ulugbekjumaev8345          NaN
# 200             http://www.youtube.com/@EdithNasser          NaN
# 1693  http://www.youtube.com/@SuriyaGomesyourbestie          NaN

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
sns.set_style('whitegrid')
# %matplotlib inline
stop=stop +['hello','good','http','love','happy','thanks','thank','heart','me','mood','video','india']
def plot_20_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names_out()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]

    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:20]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words))

    plt.figure(2, figsize=(40, 40))
    plt.subplot(title='20 most common words')
    sns.set_context("notebook", font_scale=4, rc={"lines.linewidth": 2.5})

    sns.barplot(x=x_pos, y=counts, palette='husl')
    #sns.barplot(x_pos, counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90)
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()
 # Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words=stop)
# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(df['description'])
# Visualise the 20 most common words
plot_20_most_common_words(count_data, count_vectorizer)
plt.savefig('saved_figure.png')
# Out:
# <ipython-input-20-b12b6f48ddc3>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x_pos, y=counts, palette='husl')

# %%
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 4), stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_bigram(df['description'], 8)
mydict={}
for word, freq in common_words:
    bigram_df  = pd.DataFrame(common_words, columns = ['ngram' , 'count'])
bigram_df.groupby('ngram').sum()['count'].sort_values(ascending=False).sort_values().plot.barh(title='Top 8 bigrams ', color='orange', width=.4, figsize=(12, 8), stacked = True)

#iplot(kind='bar', yTitle='Count', linecolor='black', title='Top 10 bigrams ')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <Axes: title={'center': 'Top 8 bigrams '}, ylabel='ngram'>

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.2)

# %%
from textblob import TextBlob

# %%
def get_subjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def get_polarity(text):
    return TextBlob(text).sentiment.polarity

# %%
df['subjectivity'] = df['description'].apply(get_subjectivity)
df['polarity'] = df['description'].apply(get_polarity)
df.head()
# Out:
#    id                      author  \
# 0   1  @Bestsongscollection-fj3op
# 1   2          @raquellinchen1106
# 2   3          @raquellinchen1106
# 3   4           @daisybanchro3611
# 4   5           @daisybanchro3611
#
#                                          description  \
# 0  Music 2023 New Songs - Top Best English Songs ...
# 1  ​@@linnlinn57340\'\'\'\'\'\'\'\'\'\'\'\'\'o\'\...
# 2                                  ​@@linnlinn5734\'
# 3                                                  1
# 4                                  ​@@linnlinn5734😊1
#
#                                                 guid  \
# 0                         UgylxIqy90o0KgrPxMV4AaABAg
# 1  UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tcc4N_ov6C
# 2  UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9tcc5EhrLAE
# 3  UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9teyaaT1BTh
# 4  UgylxIqy90o0KgrPxMV4AaABAg.9tTUQOMk9ce9teyc7ElVch
#
#                            to  likecount  \
# 0                         NaN        771
# 1  @Bestsongscollection-fj3op          0
# 2  @Bestsongscollection-fj3op          1
# 3  @Bestsongscollection-fj3op         52
# 4  @Bestsongscollection-fj3op          0
#
#                                                 link              pubdate  \
# 0  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-16 04:59:45
# 1  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-20 03:27:47
# 2  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-20 03:27:54
# 3  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-21 01:23:02
# 4  https://www.youtube.com/watch?v=mjO1yZyi6bM&lc...  2023-08-21 01:23:15
#
#    replycount                                              title  \
# 0         163  Music 2023 New Songs - Top Best English Songs ...
# 1           0  ​@@linnlinn57340\'\'\'\'\'\'\'\'\'\'\'\'\'o\'\...
# 2           0                                  ​@@linnlinn5734\'
# 3           0                                                  1
# 4           0                                  ​@@linnlinn5734😊1
#
#                                     authorChannelUrl  Unnamed: 11  \
# 0  http://www.youtube.com/@Bestsongscollection-fj3op          NaN
# 1          http://www.youtube.com/@raquellinchen1106          NaN
# 2          http://www.youtube.com/@raquellinchen1106          NaN
# 3           http://www.youtube.com/@daisybanchro3611          NaN
# 4           http://www.youtube.com/@daisybanchro3611          NaN
#
#    subjectivity  polarity
# 0      0.434848  0.395455
# 1      0.000000  0.000000
# 2      0.000000  0.000000
# 3      0.000000  0.000000
# 4      0.000000  0.000000

# %%
# Obtain polarity scores generated by TextBlob
df['textblob_score'] = df['description'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
neutral_threshold = 0.05

# %%
# Convert polarity score into sentiment categories
df['textblob_sentiment'] = df['textblob_score'].apply(lambda c: 'Positive' if c >= neutral_threshold else ('Negative' if c <= -(neutral_threshold) else 'Neutral'))

# %%
textblob_df = df[['description', 'textblob_sentiment', 'likecount']]
textblob_df
# Out:
#                                             description textblob_sentiment  \
# 0     Music 2023 New Songs - Top Best English Songs ...           Positive
# 1     ​@@linnlinn57340\'\'\'\'\'\'\'\'\'\'\'\'\'o\'\...            Neutral
# 2                                     ​@@linnlinn5734\'            Neutral
# 3                                                     1            Neutral
# 4                                     ​@@linnlinn5734😊1            Neutral
# ...                                                 ...                ...
# 2174  If I only could choose one group of songs I wo...            Neutral
# 2175                                            Qaaaaaq            Neutral
# 2176                                    😊😊😊😊qqaaqqqqqqq            Neutral
# 2177  พวก เพ้อฝัน หลอกลวง คนอื่นๆ น่าตา ชื่อเสียง จร...            Neutral
# 2178                                      I like it❤❤❤❤            Neutral
#
#       likecount
# 0           771
# 1             0
# 2             1
# 3            52
# 4             0
# ...         ...
# 2174          7
# 2175          0
# 2176          0
# 2177          0
# 2178          6
#
# [2179 rows x 3 columns]

# %%
textblob_df['textblob_sentiment'].value_counts()
# Out:
# textblob_sentiment
# Neutral     1190
# Positive     933
# Negative      56
# Name: count, dtype: int64

# %%
textblob_df['textblob_sentiment'].value_counts().plot.barh(title='Sentiment Analysis ', color='orange', width=.4, figsize=(10, 8), stacked = True)
# Out:
# <Axes: title={'center': 'Sentiment Analysis '}, ylabel='textblob_sentiment'>

# %%
df_positive=textblob_df[textblob_df['textblob_sentiment']=='Positive']

# %%
df_Very_positive=df_positive[df_positive['likecount']>0]

# %%
df_Very_positive.head()
# Out:
#                                           description textblob_sentiment  \
# 0   Music 2023 New Songs - Top Best English Songs ...           Positive
# 27                                      I love Alan❤❤           Positive
# 29          ❤❤❤❤❤🎉🎉🎉🎉 good keep the good job love you           Positive
# 31                                 l love alan walker           Positive
# 32  What Is The Greatest Singer 🧑‍🎤 About That Guy...           Positive
#
#     likecount
# 0         771
# 27          1
# 29          2
# 31          1
# 32          1

# %%
df_negative=textblob_df[textblob_df['textblob_sentiment']=='Negative']

# %%
df_negative.head()
# Out:
#                                            description textblob_sentiment  \
# 78                                    i mean @user-4dy           Negative
# 196                         Fuck KFC Christmas In July           Negative
# 210                   Everyday i have to come here 😂😂😂           Negative
# 219                             This is crazy song🎉🎉🎉🎉           Negative
# 232  I am "Alone" and "Faded" with my "Tired" "Diam...           Negative
#
#      likecount
# 78           0
# 196          2
# 210          0
# 219          0
# 232          1

# %%
df_neutral=textblob_df[textblob_df['textblob_sentiment']=='Neutral']

# %%
df_neutral.head()
# Out:
#                                          description textblob_sentiment  \
# 1  ​@@linnlinn57340\'\'\'\'\'\'\'\'\'\'\'\'\'o\'\...            Neutral
# 2                                  ​@@linnlinn5734\'            Neutral
# 3                                                  1            Neutral
# 4                                  ​@@linnlinn5734😊1            Neutral
# 5                                     8:33 8:35 8:36            Neutral
#
#    likecount
# 1          0
# 2          1
# 3         52
# 4          0
# 5         36

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
#Creating the text variable
positive_tw = " ".join(t for t in df_Very_positive.description)

# Creating word_cloud with text as argument in .generate() method

word_cloud1 = WordCloud(collocations = False, background_color = 'white').generate(positive_tw)

# Display the generated Word Cloud

plt.imshow(word_cloud1, interpolation='bilinear')

plt.axis("off")

plt.show()

# %%
#Creating the text variable
negative_tw = " ".join(t for t in df_negative.description)

# Creating word_cloud with text as argument in .generate() method

word_cloud2 = WordCloud(collocations = False, background_color = 'white').generate(negative_tw)

# Display the generated Word Cloud

plt.imshow(word_cloud2, interpolation='bilinear')

plt.axis("off")

plt.show()

# %%
#Creating the text variable
neutral_tw = " ".join(t for t in df_neutral.description)

# Creating word_cloud with text as argument in .generate() method

word_cloud2 = WordCloud(collocations = False, background_color = 'white').generate(neutral_tw)

# Display the generated Word Cloud

plt.imshow(word_cloud2, interpolation='bilinear')

plt.axis("off")

plt.show()
